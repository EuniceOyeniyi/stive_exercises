# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
import matplotlib

# %%
np.array(2)
# Out:
# array(2)

# %%
img = cv2.imread('..\\dog.12.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# -1

# %%
plt.figure(figsize=(8,20))
plt.imshow(img)

# %%
cv2.imwrite('opendog.png',img)
# Out:
# True

# %%
# rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(20,8))
plt.imshow(rgb_img)

# %%
# gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# plt.figure(figsize=(10,20))
# plt.imshow(gray_img, cmap='gray')

# %%
gray_img.shape
# Out:
# (161, 98)

# %%
img_copy = rgb_img.copy()
cv2.rectangle(img_copy,(80,80),(20,20),(0,255,0),2)
plt.figure(figsize=(20,15))
plt.imshow(img_copy)

# %%
img_copy = rgb_img.copy()
plt.figure(figsize=(20,15))
cv2.putText(img_copy, 'A Dog',(0,20),cv2.FONT_HERSHEY_COMPLEX,1,(255,0,0),1)
plt.imshow(img_copy)

# %%
#circles
# img_copy = rgb_img.copy()
plt.figure(figsize=(20,15))
# cv2.circle(img_copy, (60,40),20,(255,0,0),-1) #use -1 or cv2.FILLED th get the shaeded area
cv2.circle(img_copy, (60,40),10,(0,0,255),-1)
cv2.putText(img_copy, 'A Dog',(0,20),cv2.FONT_HERSHEY_COMPLEX,1,(0,0,255),1)
plt.imshow(img_copy)

# %%
cv2.__version__
# Out:
# '4.6.0'
